# %% [markdown]
# Version 1.1.0

# %% [markdown]
# # Mean encodings

# %% [markdown]
# In this programming assignment you will be working with `1C` dataset from the final competition. You are asked to encode `item_id` in 4 different ways:
#
#     1) Via KFold scheme;
#     2) Via Leave-one-out scheme;
#     3) Via smoothing scheme;
#     4) Via expanding mean scheme.
#
# **You will need to submit** the correlation coefficient between resulting encoding and target variable up to 4 decimal places.
#
# ### General tips
#
# * Fill NANs in the encoding with `0.3343`.
# * Some encoding schemes depend on sorting order, so in order to avoid confusion, please use the following code snippet to construct the data frame. This snippet also implements mean encoding without regularization.

# %%
import pandas as pd
import numpy as np
from itertools import product
from grader import Grader

# %% [markdown]
# # Read data

# %%
sales = pd.read_csv('../readonly/final_project_data/sales_train.csv.gz')

# %%
sales.head()
# Out:
#          date  date_block_num  shop_id  item_id  item_price  item_cnt_day
# 0  02.01.2013               0       59    22154      999.00           1.0
# 1  03.01.2013               0       25     2552      899.00           1.0
# 2  05.01.2013               0       25     2552      899.00          -1.0
# 3  06.01.2013               0       25     2554     1709.05           1.0
# 4  15.01.2013               0       25     2555     1099.00           1.0

# %% [markdown]
# # Aggregate data

# %% [markdown]
# Since the competition task is to make a monthly prediction, we need to aggregate the data to montly level before doing any encodings. The following code-cell serves just that purpose.

# %%
index_cols = ['shop_id', 'item_id', 'date_block_num']

# For every month we create a grid from all shops/items combinations from that month
grid = [] 
for block_num in sales['date_block_num'].unique():
    cur_shops = sales[sales['date_block_num']==block_num]['shop_id'].unique()
    cur_items = sales[sales['date_block_num']==block_num]['item_id'].unique()
    grid.append(np.array(list(product(*[cur_shops, cur_items, [block_num]])),dtype='int32'))

#turn the grid into pandas dataframe
grid = pd.DataFrame(np.vstack(grid), columns = index_cols,dtype=np.int32)

# %%
grid.head()
# Out:
#    shop_id  item_id  date_block_num
# 0       59    22154               0
# 1       59     2552               0
# 2       59     2554               0
# 3       59     2555               0
# 4       59     2564               0

# %%
#get aggregated values for (shop_id, item_id, month)
gb = sales.groupby(index_cols,as_index=False).agg({'item_cnt_day': 'sum'}) \
                                             .rename(columns={'item_cnt_day': 'target'})

# %%
gb.head()
# Out:
#    shop_id  item_id  date_block_num  target
# 0        0       30               1    31.0
# 1        0       31               1    11.0
# 2        0       32               0     6.0
# 3        0       32               1    10.0
# 4        0       33               0     3.0

# %%
gb.columns.values
# Out:
# array(['shop_id', 'item_id', 'date_block_num', 'target'], dtype=object)

# %%
# #fix column names
# gb.columns = [col[0] if col[-1]=='' else col[-1] for col in gb.columns.values]
#join aggregated data to the grid
all_data = pd.merge(grid,gb,how='left',on=index_cols).fillna(0)
#sort the data
all_data.sort_values(['date_block_num','shop_id','item_id'],inplace=True)

# %%
all_data.head()
# Out:
#         shop_id  item_id  date_block_num  target
# 139255        0       19               0     0.0
# 141495        0       27               0     0.0
# 144968        0       28               0     0.0
# 142661        0       29               0     0.0
# 138947        0       32               0     6.0

# %%
all_data.target.value_counts()
# Out:
# 0.0      9307309
# 1.0      1058825
# 2.0       265502
# 3.0       103227
# 4.0        53327
#           ...
# 369.0          1
# 370.0          1
# 371.0          1
# 373.0          1
# 228.0          1
# Name: target, Length: 446, dtype: int64

# %%
all_data.target.mean()
# Out:
# 0.3342730567123426

# %% [markdown]
# # Mean encodings without regularization

# %% [markdown]
# After we did the techinical work, we are ready to actually *mean encode* the desired `item_id` variable.
#
# Here are two ways to implement mean encoding features *without* any regularization. You can use this code as a starting point to implement regularized techniques.

# %% [markdown]
# #### Method 1

# %%
item_id_target_mean = all_data.groupby('item_id').target.mean()

# %%
item_id_target_mean
# Out:
# item_id
# 0        0.020000
# 1        0.023810
# 2        0.019802
# 3        0.019802
# 4        0.020000
#            ...
# 22165    0.021277
# 22166    0.295918
# 22167    1.081081
# 22168    0.032967
# 22169    0.020833
# Name: target, Length: 21807, dtype: float64

# %%
# Calculate a mapping: {item_id: target_mean}
item_id_target_mean = all_data.groupby('item_id').target.mean()

# In our non-regularized case we just *map* the computed means to the `item_id`'s
all_data['item_target_enc'] = all_data['item_id'].map(item_id_target_mean)

# Fill NaNs
all_data['item_target_enc'].fillna(0.3343, inplace=True) 

# Print correlation
encoded_feature = all_data['item_target_enc'].values
print(np.corrcoef(all_data['target'].values, encoded_feature)[0][1])
# Out:
# 0.4830386988621699

# %%
all_data['item_id'].map(item_id_target_mean)
# Out:
# 139255      0.022222
# 141495      0.056834
# 144968      0.141176
# 142661      0.037383
# 138947      1.319042
#               ...
# 10768834    1.556793
# 10769024    0.581395
# 10769690    1.235589
# 10771216    0.295918
# 10770511    1.081081
# Name: item_id, Length: 10913850, dtype: float64

# %%
item_id_target_mean_dict = dict(item_id_target_mean)
item_id_target_mean_dict
# Out:
# {0: 0.02,
#  1: 0.023809523809523808,
#  2: 0.019801980198019802,
#  3: 0.019801980198019802,
#  4: 0.02,
#  5: 0.02,
#  6: 0.02,
#  7: 0.02,
#  8: 0.019801980198019802,
#  9: 0.0196078431372549,
#  10: 0.02,
#  11: 0.02,
#  12: 0.021739130434782608,
#  13: 0.02,
#  14: 0.02,
#  15: 0.02,
#  16: 0.02,
#  17: 0.02,
#  18: 0.0196078431372549,
#  19: 0.022222222222222223,
#  20: 0.0196078431372549,
#  21: 0.02,
#  22: 0.02127659574468085,
#  23: 0.02127659574468085,
#  24: 0.02127659574468085,
#  25: 0.0196078431372549,
#  26: 0.019230769230769232,
#  27: 0.056833558863328824,
#  28: 0.1411764705882353,
#  29: 0.037383177570093455,
#  30: 1.355613238157041,
#  31: 0.9312134977287476,
#  32: 1.3190416141235812,
#  33: 0.5271122320302648,
#  34: 0.14610778443113773,
#  35: 0.9446808510638298,
#  36: 0.06913996627318718,
#  37: 0.15311510031678988,
#  38: 0.09984871406959153,
#  39: 0.03867403314917127,
#  40: 0.0709433962264151,
#  41: 0.08582834331337326,
#  42: 0.0705958549222798,
#  43: 0.032846715328467155,
#  44: 0.08677337826453244,
#  45: 0.11097099621689786,
#  46: 0.05844980940279543,
#  47: 0.07604017216642754,
#  48: 0.06900452488687783,
#  49: 0.11664564943253468,
#  50: 0.044444444444444446,
#  51: 0.14880201765447668,
#  52: 0.0672358591248666,
#  53: 0.11979823455233292,
#  54: 0.07312614259597806,
#  55: 0.1125748502994012,
#  56: 0.05298913043478261,
#  57: 0.09836065573770492,
#  58: 0.022222222222222223,
#  59: 0.1574854180168503,
#  60: 0.07116788321167883,
#  61: 0.043795620437956206,
#  62: 0.17703349282296652,
#  63: 0.05625,
#  64: 0.1426403641881639,
#  65: 0.06016042780748663,
#  66: 0.09370199692780339,
#  67: 0.2621082621082621,
#  68: 0.021739130434782608,
#  69: 0.35294117647058826,
#  70: 0.35947712418300654,
#  71: 0.04574132492113565,
#  72: 0.07397959183673469,
#  73: 0.03272727272727273,
#  74: 0.042662116040955635,
#  75: 0.07846153846153846,
#  76: 0.4473684210526316,
#  77: 1.0956749672346002,
#  78: 0.4263803680981595,
#  810: 0.0975609756097561,
#  811: 0.03484320557491289,
#  812: 0.01990049751243781,
#  813: 0.022222222222222223,
#  814: 0.10136986301369863,
#  815: 0.03296703296703297,
#  816: 0.05625,
#  817: 0.020689655172413793,
#  818: 0.02142857142857143,
#  819: 0.03761755485893417,
#  820: 0.02054794520547945,
#  821: 0.03375527426160337,
#  822: 0.04891304347826087,
#  823: 0.02553191489361702,
#  824: 0.022222222222222223,
#  825: 0.10218978102189781,
#  826: 0.03355704697986577,
#  827: 0.029649595687331536,
#  828: 0.022222222222222223,
#  829: 0.22761664564943254,
#  830: 0.028469750889679714,
#  831: 0.08235294117647059,
#  832: 0.2540983606557377,
#  833: 0.1556122448979592,
#  834: 0.044444444444444446,
#  835: 0.3890290037831021,
#  836: 0.03676470588235294,
#  837: 0.0632279534109817,
#  838: 0.09907341411261582,
#  839: 0.776796973518285,
#  840: 0.021739130434782608,
#  841: 0.020134228187919462,
#  842: 0.027184466019417475,
#  843: 0.03333333333333333,
#  844: 0.031578947368421054,
#  845: 0.021739130434782608,
#  846: 0.034013605442176874,
#  847: 0.029013539651837523,
#  848: 0.02102803738317757,
#  849: 0.05073649754500818,
#  850: 0.023255813953488372,
#  851: 0.030120481927710843,
#  852: 0.020833333333333332,
#  853: 0.029166666666666667,
#  854: 0.021739130434782608,
#  855: 0.021739130434782608,
#  856: 0.025974025974025976,
#  857: 0.021739130434782608,
#  858: 0.025362318840579712,
#  859: 0.0291005291005291,
#  860: 0.021739130434782608,
#  861: 0.022222222222222223,
#  862: 0.03333333333333333,
#  863: 0.023255813953488372,
#  864: 0.027237354085603113,
#  865: 0.0213903743315508,
#  866: 0.022727272727272728,
#  867: 0.033468559837728194,
#  868: 0.05327413984461709,
#  869: 0.04704097116843703,
#  870: 0.021739130434782608,
#  871: 0.03,
#  872: 0.022222222222222223,
#  873: 0.021739130434782608,
#  874: 0.023722627737226276,
#  875: 0.03225806451612903,
#  876: 0.022222222222222223,
#  877: 0.03125,
#  878: 0.021739130434782608,
#  879: 0.039473684210526314,
#  880: 0.021897810218978103,
#  881: 0.021739130434782608,
#  882: 0.03134796238244514,
#  883: 0.043478260869565216,
#  884: 0.021739130434782608,
#  885: 0.03140495867768595,
#  886: 0.021739130434782608,
#  887: 0.025547445255474453,
#  888: 0.021739130434782608,
#  889: 0.02586206896551724,
#  890: 0.031210986267166042,
#  891: 0.03403565640194489,
#  893: 0.02247191011235955,
#  894: 0.024916943521594685,
#  895: 0.021739130434782608,
#  896: 0.028744326777609682,
#  897: 0.029619181946403384,
#  898: 0.022727272727272728,
#  899: 0.03597122302158273,
#  901: 0.043478260869565216,
#  902: 0.030973451327433628,
#  903: 0.036637931034482756,
#  904: 0.030894308943089432,
#  905: 0.020134228187919462,
#  906: 0.026785714285714284,
#  908: 0.025974025974025976,
#  909: 0.021739130434782608,
#  910: 0.025547445255474453,
#  911: 0.026737967914438502,
#  912: 0.028642590286425903,
#  913: 0.02132701421800948,
#  914: 0.02147239263803681,
#  915: 0.025052192066805846,
#  916: 0.04126984126984127,
#  917: 0.05367231638418079,
#  918: 0.030585106382978722,
#  919: 0.02127659574468085,
#  920: 0.022222222222222223,
#  921: 0.029661016949152543,
#  922: 0.022222222222222223,
#  923: 0.021739130434782608,
#  924: 0.026246719160104987,
#  925: 0.023255813953488372,
#  926: 0.02,
#  927: 0.05970149253731343,
#  928: 0.023255813953488372,
#  929: 0.022727272727272728,
#  930: 0.022727272727272728,
#  931: 0.022727272727272728,
#  932: 0.022727272727272728,
#  933: 0.057245080500894455,
#  934: 0.6280353200883002,
#  935: 0.5871404399323181,
#  936: 0.16666666666666666,
#  937: 0.04020100502512563,
#  938: 0.02,
#  939: 0.02,
#  940: 0.02,
#  941: 0.028846153846153848,
#  942: 0.021739130434782608,
#  943: 0.02717391304347826,
#  944: 0.39274924471299094,
#  945: 0.0571870170015456,
#  946: 0.03508771929824561,
#  947: 0.08280254777070063,
#  948: 0.38320209973753283,
#  949: 0.5189542483660131,
#  950: 0.6514778325123153,
#  951: 0.37037037037037035,
#  952: 0.08181818181818182,
#  953: 0.09472049689440994,
#  954: 0.025974025974025976,
#  955: 0.02197802197802198,
#  956: 0.10019646365422397,
#  957: 0.6666666666666666,
#  958: 0.07983623336745138,
#  959: 0.14007782101167315,
#  960: 0.7249283667621776,
#  961: 0.35260115606936415,
#  962: 0.23607427055702918,
#  963: 0.3204930662557781,
#  964: 0.09357798165137615,
#  965: 0.1695264241592313,
#  966: 0.02,
#  967: 0.1566265060240964,
#  968: 0.83645443196005,
#  969: 0.37952559300873906,
#  970: 0.39337474120082816,
#  971: 0.47289586305278175,
#  972: 1.8531717747683536,
#  973: 0.050156739811912224,
#  974: 0.10991379310344827,
#  975: 0.5943172849250198,
#  976: 0.05167173252279635,
#  977: 0.09156976744186046,
#  978: 0.1930541368743616,
#  979: 0.19490254872563717,
#  980: 0.20902255639097744,
#  981: 0.58,
#  982: 0.579047619047619,
#  983: 0.1843687374749499,
#  984: 1.27,
#  985: 0.04081632653061224,
#  986: 0.022727272727272728,
#  987: 0.23151750972762647,
#  988: 0.20108695652173914,
#  989: 0.16819852941176472,
#  990: 0.20184331797235022,
#  991: 0.28351012536162007,
#  992: 0.13984168865435356,
#  993: 0.2613981762917933,
#  994: 0.0676246830092984,
#  995: 0.07107843137254902,
#  996: 0.13984375,
#  997: 0.052833813640730067,
#  998: 0.41475826972010177,
#  999: 0.3880445795339412,
#  1000: 0.23389830508474577,
#  1001: 0.2227579556412729,
#  1002: 0.2826747720364742,
#  1003: 0.3573844419391206,
#  1004: 0.43641912512716174,
#  1005: 0.2471042471042471,
#  1006: 0.24132947976878613,
#  1007: 0.9117276166456494,
#  1008: 0.1414141414141414,
#  1009: 0.11125,
#  1010: 0.362547288776797,
#  1011: 0.050059594755661505,
#  1012: 0.1090458488228005,
#  1013: 0.25722543352601157,
#  1014: 0.22426470588235295,
#  1015: 0.725018234865062,
#  1016: 0.2941961307538359,
#  1017: 0.29965635738831614,
#  1018: 0.12054439403758911,
#  1019: 0.296969696969697,
#  1020: 0.13869625520110956,
#  ...}

# %%
all_data['item_id'].map(item_id_target_mean_dict)
# Out:
# 139255      0.022222
# 141495      0.056834
# 144968      0.141176
# 142661      0.037383
# 138947      1.319042
#               ...
# 10768834    1.556793
# 10769024    0.581395
# 10769690    1.235589
# 10771216    0.295918
# 10770511    1.081081
# Name: item_id, Length: 10913850, dtype: float64

# %% [markdown]
# #### Method 2

# %%
all_data.groupby('item_id').target.mean()
# Out:
# item_id
# 0        0.020000
# 1        0.023810
# 2        0.019802
# 3        0.019802
# 4        0.020000
#            ...
# 22165    0.021277
# 22166    0.295918
# 22167    1.081081
# 22168    0.032967
# 22169    0.020833
# Name: target, Length: 21807, dtype: float64

# %%
all_data.groupby('item_id')['target'].transform('mean')
# Out:
# 139255      0.022222
# 141495      0.056834
# 144968      0.141176
# 142661      0.037383
# 138947      1.319042
#               ...
# 10768834    1.556793
# 10769024    0.581395
# 10769690    1.235589
# 10771216    0.295918
# 10770511    1.081081
# Name: target, Length: 10913850, dtype: float64

# %%
'''
     Differently to `.target.mean()` function `transform` 
   will return a dataframe with an index like in `all_data`.
   Basically this single line of code is equivalent to the first two lines from of Method 1.
'''
all_data['item_target_enc'] = all_data.groupby('item_id')['target'].transform('mean')

# Fill NaNs
all_data['item_target_enc'].fillna(0.3343, inplace=True) 

# Print correlation
encoded_feature = all_data['item_target_enc'].values
print(np.corrcoef(all_data['target'].values, encoded_feature)[0][1])
# Out:
# 0.4830386988621699

# %% [markdown]
# See the printed value? It is the correlation coefficient between the target variable and your new encoded feature. You need to **compute correlation coefficient** between the encodings, that you will implement and **submit those to coursera**.

# %%
grader = Grader()

# %% [markdown]
# # 1. KFold scheme

# %% [markdown]
# Explained starting at 41 sec of [Regularization video](https://www.coursera.org/learn/competitive-data-science/lecture/LGYQ2/regularization).

# %% [markdown]
# **Now it's your turn to write the code!**
#
# You may use 'Regularization' video as a reference for all further tasks.
#
# First, implement KFold scheme with five folds. Use KFold(5) from sklearn.model_selection.
#
# 1. Split your data in 5 folds with `sklearn.model_selection.KFold` with `shuffle=False` argument.
# 2. Iterate through folds: use all but the current fold to calculate mean target for each level `item_id`, and  fill the current fold.
#
#     *  See the **Method 1** from the example implementation. In particular learn what `map` and pd.Series.map functions do. They are pretty handy in many situations.

# %%
all_data.head()
# Out:
#         shop_id  item_id  date_block_num  target
# 139255        0       19               0     0.0
# 141495        0       27               0     0.0
# 144968        0       28               0     0.0
# 142661        0       29               0     0.0
# 138947        0       32               0     6.0

# %%
all

# %%
all_data = all_data.drop('item_target_enc', axis=1)

# %%
from sklearn.model_selection import KFold

# %%
all_data['item_target_enc'] = 0.

# %%
all_data
# Out:
#           shop_id  item_id  date_block_num  target  item_target_enc
# 139255          0       19               0     0.0              0.0
# 141495          0       27               0     0.0              0.0
# 144968          0       28               0     0.0              0.0
# 142661          0       29               0     0.0              0.0
# 138947          0       32               0     6.0              0.0
# ...           ...      ...             ...     ...              ...
# 10768834       59    22162              33     0.0              0.0
# 10769024       59    22163              33     0.0              0.0
# 10769690       59    22164              33     0.0              0.0
# 10771216       59    22166              33     0.0              0.0
# 10770511       59    22167              33     0.0              0.0
#
# [10913850 rows x 5 columns]

# %%
all_data['item_target_enc'].loc[[0, 1]]
# Out:
# 0    0.3343
# 1    0.3343
# Name: item_target_enc, dtype: float64

# %%
all_data['item_target_enc'].loc[test_index]
# Out:
# 8731080     0.3343
# 8731081     0.3343
# 8731082     0.3343
# 8731083     0.3343
# 8731084     0.3343
#              ...
# 10913845    0.3343
# 10913846    0.3343
# 10913847    0.3343
# 10913848    0.3343
# 10913849    0.3343
# Name: item_target_enc, Length: 2182770, dtype: float64

# %%
all_data['item_id'].loc[test_index].map(all_data.loc[train_index].groupby('item_id').target.mean())
# Out:
# 8731080     1.352113
# 8731081     0.402192
# 8731082     0.133460
# 8731083     0.220000
# 8731084     0.343170
#               ...
# 10913845         NaN
# 10913846    0.020408
# 10913847         NaN
# 10913848    0.020202
# 10913849         NaN
# Name: item_id, Length: 2182770, dtype: float64

# %%
all_data['item_target_enc'].loc[test_index] = all_data['item_id'].loc[test_index].map(all_data.loc[train_index].groupby('item_id').target.mean())
# Out:
# /home/ivan/venvs/kaggle/lib/python3.7/site-packages/pandas/core/indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)

# %%
all_data['item_id'].loc[test_index].map(all_data.loc[train_index].groupby('item_id').target.mean()).fillna(0.)
# Out:
# 8731080     1.352113
# 8731081     0.402192
# 8731082     0.133460
# 8731083     0.220000
# 8731084     0.343170
#               ...
# 10913845    0.000000
# 10913846    0.020408
# 10913847    0.000000
# 10913848    0.020202
# 10913849    0.000000
# Name: item_id, Length: 2182770, dtype: float64

# %%
all_data['item_target_enc'] += all_data['item_id'].loc[test_index].map(all_data.loc[train_index].groupby('item_id').target.mean()).fillna(0.)

# %%
all_data['item_target_enc'].loc[test_index]
# Out:
# 8731080     1.352113
# 8731081     0.402192
# 8731082     0.133460
# 8731083     0.220000
# 8731084     0.343170
#               ...
# 10913845    0.000000
# 10913846    0.020408
# 10913847    0.000000
# 10913848    0.020202
# 10913849    0.000000
# Name: item_target_enc, Length: 2182770, dtype: float64

# %%
testset = all_data['item_target_enc'].loc[test_index]

# %%
part1 = testset[:10]
part2 = testset[10:20]

# %%
part1
# Out:
# 8731080    1.352113
# 8731081    0.402192
# 8731082    0.133460
# 8731083    0.220000
# 8731084    0.343170
# 8731085    0.333333
# 8731086    0.225000
# 8731087    1.393939
# 8731088    0.535354
# 8731089    1.969697
# Name: item_target_enc, dtype: float64

# %%
part2
# Out:
# 8731090    0.515152
# 8731091    1.181818
# 8731092    2.101010
# 8731093    1.353535
# 8731094    0.666948
# 8731095    0.290894
# 8731096    1.484848
# 8731097    1.686869
# 8731098    3.121212
# 8731099    0.029412
# Name: item_target_enc, dtype: float64

# %%
pd.concat([part1, part2])
# Out:
# 8731080    1.352113
# 8731081    0.402192
# 8731082    0.133460
# 8731083    0.220000
# 8731084    0.343170
# 8731085    0.333333
# 8731086    0.225000
# 8731087    1.393939
# 8731088    0.535354
# 8731089    1.969697
# 8731090    0.515152
# 8731091    1.181818
# 8731092    2.101010
# 8731093    1.353535
# 8731094    0.666948
# 8731095    0.290894
# 8731096    1.484848
# 8731097    1.686869
# 8731098    3.121212
# 8731099    0.029412
# Name: item_target_enc, dtype: float64

# %%
all_data.loc[train_index].groupby('item_id').target.mean()
# Out:
# item_id
# 0        0.020000
# 1        0.023810
# 2        0.019802
# 3        0.019802
# 4        0.020000
#            ...
# 22165    0.021277
# 22166    0.349227
# 22167    1.229927
# 22168    0.032967
# 22169    0.020833
# Name: target, Length: 19244, dtype: float64

# %%
kf = KFold(n_splits=5)

enc_feat_list = []
for train_index, test_index in kf.split(all_data):
    enc_feat_list.append(all_data['item_id'].loc[test_index].map(all_data.loc[train_index].groupby('item_id').target.mean()))

all_data['item_target_enc'] = pd.concat(enc_feat_list)

# %%
pd.concat(enc_feat_list)
# Out:
# 0           0.084746
# 1           0.021583
# 2                NaN
# 3           0.056995
# 4           0.040307
#               ...
# 10913845         NaN
# 10913846    0.020408
# 10913847         NaN
# 10913848    0.020202
# 10913849         NaN
# Name: item_id, Length: 10913850, dtype: float64

# %%
all_data['item_target_enc'].fillna(0.3343, inplace=True)

# %%
encoded_feature = all_data['item_target_enc'].values

# You will need to compute correlation like that
corr = np.corrcoef(all_data['target'].values, encoded_feature)[0][1]
print(corr)
grader.submit_tag('KFold_scheme', corr)
# Out:
# 0.4166330182247348
# Current answer for task KFold_scheme is: 0.4166330182247348

# %% [markdown]
# # 2. Leave-one-out scheme

# %% [markdown]
# Now, implement leave-one-out scheme. Note that if you just simply set the number of folds to the number of samples and run the code from the **KFold scheme**, you will probably wait for a very long time.
#
# To implement a faster version, note, that to calculate mean target value using all the objects but one *given object*, you can:
#
# 1. Calculate sum of the target values using all the objects.
# 2. Then subtract the target of the *given object* and divide the resulting value by `n_objects - 1`.
#
# Note that you do not need to perform `1.` for every object. And `2.` can be implemented without any `for` loop.
#
# It is the most convenient to use `.transform` function as in **Method 2**.

# %%
all_data = all_data.drop('item_target_enc', axis=1)
all_data.head()
# Out:
#         shop_id  item_id  date_block_num  target
# 139255        0       19               0     0.0
# 141495        0       27               0     0.0
# 144968        0       28               0     0.0
# 142661        0       29               0     0.0
# 138947        0       32               0     6.0

# %%
means_by_item_id = all_data.groupby('item_id').target.sum()
lens_by_item_i = all_data.groupby('item_id').target.count()

# %%
all_data['item_target_enc'] = (all_data['item_id'].map(means_by_item_id) - all_data['target']) / all_data['item_id'].map(lens_by_item_i - 1)

all_data['item_target_enc'].fillna(0.3343, inplace=True) 

encoded_feature = all_data['item_target_enc'].values

corr = np.corrcoef(all_data['target'].values, encoded_feature)[0][1]
print(corr)
grader.submit_tag('Leave-one-out_scheme', corr)
# Out:
# 0.4803848311293002
# Current answer for task Leave-one-out_scheme is: 0.4803848311293002

# %%
all_data.item_target_enc.value_counts()
# Out:
# 0.334273    9307309
# 0.334273    1058825
# 0.334273     265502
# 0.334273     103227
# 0.334273      53327
#              ...
# 0.334203          1
# 0.334228          1
# 0.334186          1
# 0.334240          1
# 0.334233          1
# Name: item_target_enc, Length: 446, dtype: int64

# %% [markdown]
# # 3. Smoothing

# %% [markdown]
# Explained starting at 4:03 of [Regularization video](https://www.coursera.org/learn/competitive-data-science/lecture/LGYQ2/regularization).

# %% [markdown]
# Next, implement smoothing scheme with $\alpha = 100$. Use the formula from the first slide in the video and $0.3343$ as `globalmean`. Note that `nrows` is the number of objects that belong to a certain category (not the number of rows in the dataset).

# %%
all_data = all_data.drop('item_target_enc', axis=1)

# %%
means_by_item_id = all_data.groupby('item_id').target.mean()
lens_by_item_i = all_data.groupby('item_id').target.count()

# %%
all_data['item_target_enc'] = (all_data['item_id'].map(means_by_item_id) * all_data['item_id'].map(lens_by_item_i) \
                               + 0.3343 * 100) / (all_data['item_id'].map(lens_by_item_i) + 100)

all_data['item_target_enc'].fillna(0.3343, inplace=True) 

encoded_feature = all_data['item_target_enc'].values

corr = np.corrcoef(all_data['target'].values, encoded_feature)[0][1]
print(corr)
grader.submit_tag('Smoothing_scheme', corr)
# Out:
# 0.4818198797097264
# Current answer for task Smoothing_scheme is: 0.4818198797097264

# %% [markdown]
# # 4. Expanding mean scheme

# %% [markdown]
# Explained starting at 5:50 of [Regularization video](https://www.coursera.org/learn/competitive-data-science/lecture/LGYQ2/regularization).

# %% [markdown]
# Finally, implement the *expanding mean* scheme. It is basically already implemented for you in the video, but you can challenge yourself and try to implement it yourself. You will need [`cumsum`](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.core.groupby.DataFrameGroupBy.cumsum.html) and [`cumcount`](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.core.groupby.GroupBy.cumcount.html) functions from pandas.

# %%
cumsum = all_data.groupby('item_id').target.cumsum() - all_data['target']
cumcnt = all_data.groupby('item_id').target.cumcount()

# %%
len(cumcnt)
# Out:
# 10913850

# %%
cumsum.reset_index()
# Out:
#              index  target
# 0           139255     0.0
# 1           141495     0.0
# 2           144968     0.0
# 3           142661     0.0
# 4           138947     0.0
# ...            ...     ...
# 10913845  10768834   699.0
# 10913846  10769024    75.0
# 10913847  10769690   493.0
# 10913848  10771216   348.0
# 10913849  10770511  1320.0
#
# [10913850 rows x 2 columns]

# %%
all_data['item_target_enc'] = cumsum / cumcnt

all_data
# Out:
#           shop_id  item_id  date_block_num  target  item_target_enc
# 139255          0       19               0     0.0              NaN
# 141495          0       27               0     0.0              NaN
# 144968          0       28               0     0.0              NaN
# 142661          0       29               0     0.0              NaN
# 138947          0       32               0     6.0              NaN
# ...           ...      ...             ...     ...              ...
# 10768834       59    22162              33     0.0         1.560268
# 10769024       59    22163              33     0.0         0.585938
# 10769690       59    22164              33     0.0         1.238693
# 10771216       59    22166              33     0.0         0.296170
# 10770511       59    22167              33     0.0         1.081967
#
# [10913850 rows x 5 columns]

# %%
all_data['item_target_enc'].fillna(0.3343, inplace=True) 

encoded_feature = all_data['item_target_enc'].values

corr = np.corrcoef(all_data['target'].values, encoded_feature)[0][1]
print(corr)
grader.submit_tag('Expanding_mean_scheme', corr)
# Out:
# 0.5025245211081697
# Current answer for task Expanding_mean_scheme is: 0.5025245211081697

# %% [markdown]
# ## Authorization & Submission
# To submit assignment parts to Cousera platform, please, enter your e-mail and token into variables below. You can generate token on this programming assignment page. Note: Token expires 30 minutes after generation.

# %%
STUDENT_EMAIL = ''
STUDENT_TOKEN = ''
grader.status()
# Out:
# You want to submit these numbers:
# Task KFold_scheme: 0.4166330182247348
# Task Leave-one-out_scheme: 0.4803848311293002
# Task Smoothing_scheme: 0.4818198797097264
# Task Expanding_mean_scheme: 0.5025245211081697

# %%
grader.submit(STUDENT_EMAIL, STUDENT_TOKEN)
# Out:
# Submitted to Coursera platform. See results on assignment page!
